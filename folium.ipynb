# %%
import folium
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv('8,9,2023.csv'))
df.dtypes
df
# Out:
#     Unnamed: 0   id  Latitude  Longtitude     Day      Date      Time
# 0            0    3   -6.9222    107.6069  Friday  8,9,2023  16:17:41
# 1            1   18   -6.9222    107.6070  Friday  8,9,2023  16:17:41
# 2            2   22   -6.9222    107.6071  Friday  8,9,2023  16:17:41
# 3            3   27   -6.9222    107.6069  Friday  8,9,2023  16:17:41
# 4            4    0   -6.9222    107.6069  Friday  8,9,2023  16:17:41
# ..         ...  ...       ...         ...     ...       ...       ...
# 72          72  386   -6.9222    107.6069  Friday  8,9,2023  16:17:41
# 73          73  392   -6.9222    107.6069  Friday  8,9,2023  16:17:41
# 74          74  398   -6.9222    107.6069  Friday  8,9,2023  16:17:41
# 75          75  399   -6.9222    107.6069  Friday  8,9,2023  16:17:41
# 76          76  411   -6.9222    107.6069  Friday  8,9,2023  16:17:41
#
# [77 rows x 7 columns]

# %%
n = folium.Map(location=(df['Latitude'][0],df['Longtitude'][0]),tiles="OpenStreetMap", zoom_start=25)

for i in range(0,len(df)) :
    folium.Marker(
        location=[df.iloc[i]['Latitude'], df.iloc[i]['Longtitude']],
        popup=f"id = {df.iloc[i]['id']}",draggable=True
    ).add_to(n)

n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecfdeb3bbd5ecbd8d0a918a0dc97da0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecfdeb3bbd5ecbd8d0a918a0dc97da0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ecfdeb3bbd5ecbd8d0a918a0dc97da0c = L.map(
#                 &quot;map_ecfdeb3bbd5ecbd8d0a918a0dc97da0c&quot;,
#                 {
#                     center: [-6.9222, 107.6069],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08df9fc4fb8e3c116812032ab22bf43c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ecfdeb3bbd5ecbd8d0a918a0dc97da0c);
#
#
#             var marker_09059633cf88d818ea41c1c7e5da0c91 = L.marker(
#                 [-6.9222, 107.6069],
#                 {}
#             ).addTo(map_ecfdeb3bbd5ecbd8d0a918a0dc97da0c);
#
#
#         var popup_8aadaf39a0c1920175402f60c0d64b70 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d21cae81b04d395e10ba7ee2ac236a2f = $(`&lt;div id=&quot;html_d21cae81b04d395e10ba7ee2ac236a2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id = 3&lt;/div&gt;`)[0];
#                 popup_8aadaf39a0c1920175402f60c0d64b70.setContent(html_d21cae81b04d395e10ba7ee2ac236a2f);
#
#
#
#         marker_09059633cf88d818ea41c1c7e5da0c91.bindPopup(popup_8aadaf39a0c1920175402f60c0d64b70)
#         ;
#
#
#
#
#             var marker_f4ec2913b0532d994133d5cde4827de5 = L.marker(
#                 [-6.9222, 107.607],
#                 {}
#             ).addTo(map_ecfdeb3bbd5ecbd8d0a918a0dc97da0c);
#
#
#         var popup_f46e2a96c7e1ae1e6c8fcd758780a7d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e99f9f83d50a22c3b44c24e5ecd12d50 = $(`&lt;div id=&quot;html_e99f9f83d50a22c3b44c24e5ecd12d50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id = 18&lt;/div&gt;`)[0];
#                 popup_f46e2a96c7e1ae1e6c8fcd758780a7d7.setContent(html_e99f9f83d50a22c3b44c24e5ecd12d50);
#
#
#
#         marker_f4ec2913b0532d994133d5cde4827de5.bindPopup(popup_f46e2a96c7e1ae1e6c8fcd758780a7d7)
#         ;
#
#
#
#
#             var marker_dfd36fd9d0358917c3686409a70e2b40 = L.marker(
#                 [-6.9222, 107.6071],
#                 {}
#             ).addTo(map_ecfdeb3bbd5ecbd8d0a918a0dc97da0c);
#
#
#         var popup_c881ae4d8284dabab7f4bfc5830a9b42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8768bd928cf1a9ba82fa6aac1a07ee8 = $(`&lt;div id=&quot;html_a8768bd928cf1a9ba82fa6aac1a07ee8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id = 22&lt;/div&gt;`)[0];
#                 popup_c881ae4d8284dabab7f4bfc5830a9b42.setContent(html_a8768bd928cf1a9ba82fa6aac1a07ee8);
#
#
#
#         marker_dfd36fd9d0358917c3686409a70e2b40.bindPopup(popup_c881ae4d8284dabab7f4bfc5830a9b42)
#         ;
#
#
#
#
#             var marker_c8da39b6f0a1e61895e988db1cc76a5d = L.marker(
#                 [-6.9222, 107.6069],
#                 {}
#             ).addTo(map_ecfdeb3bbd5ecbd8d0a918a0dc97da0c);
#
#
#         var popup_c99eca9b39dfd6f35bc3b11ad532660c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0422e754188e6bd7384c9ff2b9b9b8b1 = $(`&lt;div id=&quot;html_0422e754188e6bd7384c9ff2b9b9b8b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id = 27&lt;/div&gt;`)[0];
#                 popup_c99eca9b39dfd6f35bc3b11ad532660c.setContent(html_0422e754188e6bd7384c9ff2b9b9b8b1);
#
#
#
#         marker_c8da39b6f0a1e61895e988db1cc76a5d.bindPopup(popup_c99eca9b39dfd6f35bc3b11ad532660c)
#         ;
#
#
#
#
#             var marker_5a40952b57bf6811dcf4408e5fcd9ecd = L.marker(
#                 [-6.9222, 107.6069],
#                 {}
#             ).addTo(map_ecfdeb3bbd5ecbd8d0a918a0dc97da0c);
#
#
#         var popup_a5b9f7d2006616a5806ae3ed865d98c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a19c6d2a9d392b849dd7bf89fdc2f93 = $(`&lt;div id=&quot;html_1a19c6d2a9d392b849dd7bf89fdc2f93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id = 0&lt;/div&gt;`)[0];
#                 popup_a5b9f7d2006616a5806ae3ed865d98c0.setContent(html_1a19c6d2a9d392b849dd7bf89fdc2f93);
#
#
#
#         marker_5a40952b57bf6811dcf4408e5fcd9ecd.bindPopup(popup_a5b9f7d2006616a5806ae3ed865d98c0)
#         ;
#
#
#
#
#             var marker_24c739f3d1326a7c4cd0673fb29d2ea1 = L.marker(
#                 [-6.9222, 107.6069],
#                 {}
#             ).addTo(map_ecfdeb3bbd5ecbd8d0a918a0dc9
